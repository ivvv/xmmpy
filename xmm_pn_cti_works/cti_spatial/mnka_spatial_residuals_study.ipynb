# %% [markdown]
# # Analysis of spatial residuals for Mn K$\alpha$
#
# Will analyse the spatial residuals at 6 keV using the Mn K$\alpha$ line after applying the spatial offsets dervied using the Cu K$\alpha$ line at 8 keV.

# %%
import os

from plot_spatial_cti import plot_spatial_cti, plot_spatial_cti_all

# %% [markdown]
# ## Spatial distribution of Mn K$\alpha$
#
# The calibration source illuminates the EPIC-pn detector unevenly, as can be seen in the figure below.

# %%
res_dir = '/xdata/xcaldata/XMM/IVAN/sanders/stacks500_0056/results_picorr_mnka'
rev_step = 500
start_rev = 1000
end_rev = 1000 + rev_step - 1
res_file = f'{res_dir}/FF_stacked_{start_rev:04}_{end_rev:04}_mnka.fits.gz'
if (os.path.isfile(res_file)):
    plot_spatial_cti_all(res_file)
else:
    print (f'Cannot find {res_file}')
#
# Out:
# CCD 1, stats: (-1.270404, -0.77558595, 14.835724)
# CCD 2, stats: (-1.9569477, -1.5890625, 14.949871)
# CCD 3, stats: (-2.5287766, -1.4264648, 18.516079)
# CCD 4, stats: (3.9350646, 4.8875, 16.309772)
# CCD 5, stats: (1.4797924, 2.4226563, 17.565193)
# CCD 6, stats: (0.2223362, 1.7361329, 16.881767)
# CCD 7, stats: (-0.8437967, -0.05292969, 16.088951)
# CCD 8, stats: (-0.57245016, -0.5626953, 17.67099)
# CCD 9, stats: (0.051219493, -0.08173828, 18.539034)
# CCD 10, stats: (-4.802086, -4.9103518, 20.15184)
# CCD 11, stats: (4.80662, 5.3396482, 23.06997)
# CCD 12, stats: (1.8317907, -0.6515625, 24.636316)
# True
